# %% [markdown]
# At the end I only used the data which was containing the trains in the 'Szombathely' line

# %%
import pandas as pd
import numpy as np

# %%
df1=df[df['Number']==910]
df1=df1.reset_index(drop=True)

# %%
df2=df[df['Number']==912]
df2=df2.reset_index(drop=True)

# %%
df3=df[df['Number']==922]
df3=df3.reset_index(drop=True)

# %%
df4=df[df['Number']==914]
df4=df4.reset_index(drop=True)

# %%
df5=df[df['Number']==924]
df5=df5.reset_index(drop=True)

# %%
df6=df[df['Number']==916]
df6=df6.reset_index(drop=True)

# %%
df7=df[df['Number']==318]
df7=df7.reset_index(drop=True)

# %%
df8=df[df['Number']==919]
df8=df8.reset_index(drop=True)

# %%
df9=df[df['Number']==917]
df9=df9.reset_index(drop=True)

# %%
df10=df[df['Number']==317]
df10=df10.reset_index(drop=True)

# %%
df11=df[df['Number']==927]
df11=df11.reset_index(drop=True)

# %%
df12=df[df['Number']==915]
df12=df12.reset_index(drop=True)

# %%
df13=df[df['Number']==925]
df13=df13.reset_index(drop=True)

# %%
df14=df[df['Number']==913]
df14=df14.reset_index(drop=True)

# %%
df15=df[df['Number']==911]
df15=df15.reset_index(drop=True)

# %%
dfs=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15], axis=0)
dfs=dfs.reset_index(drop=True)
dfs
# Out:
#               Date  Number             From               To  First_class  \
# 0       2019-01-01     910  Budapest-Keleti        Tatabánya            0
# 1       2019-01-01     910  Budapest-Keleti          Komárom            0
# 2       2019-01-01     910  Budapest-Keleti             Győr            4
# 3       2019-01-01     910  Budapest-Keleti           Csorna            2
# 4       2019-01-01     910  Budapest-Keleti      Szombathely            3
# ...            ...     ...              ...              ...          ...
# 115894  2019-12-30     911             Győr        Kelenföld            0
# 115895  2019-12-30     911             Győr  Budapest-Keleti            2
# 115896  2019-12-30     911          Komárom        Kelenföld            0
# 115897  2019-12-30     911          Komárom  Budapest-Keleti            0
# 115898  2019-12-30     911             Tata  Budapest-Keleti            0
#
#         Second_class  Distances  Price_2  Price      Day  ...  Season  \
# ...
